# %%
greeting = "  Hello, little people of Earth!      "

print(len(greeting))

if (len(greeting) % 3) == 0:
    print('divides evenly')

new_greeting = greeting.strip()
print(new_greeting)

new_str = new_greeting[0:5]
print(new_str)

stop = 0
while stop != 72:
    new_str += 'o'
    stop += 1
print(new_str)
# Out:
# 38
# Hello, little people of Earth!
# Hello
# Hellooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo

# %%
def main():
    for num in range(41,90):
        wow_kazow(num)

def wow_kazow(num):
    if (num % 5) == 0:
        print('Wow')
    elif (num % 7) == 0:
        print('Kazow')
    elif (num % 5) == 0 and (num % 7) == 0:
        print('WowKazow')
    else:
        print(f'{num} is not dividable')
if __name__ == '__main__':
    # call main 
    main()
# Out:
# 41 is not dividable
# Kazow
# 43 is not dividable
# 44 is not dividable
# Wow
# 46 is not dividable
# 47 is not dividable
# 48 is not dividable
# Kazow
# Wow
# 51 is not dividable
# 52 is not dividable
# 53 is not dividable
# 54 is not dividable
# Wow
# Kazow
# 57 is not dividable
# 58 is not dividable
# 59 is not dividable
# Wow
# 61 is not dividable
# 62 is not dividable
# Kazow
# 64 is not dividable
# Wow
# 66 is not dividable
# 67 is not dividable
# 68 is not dividable
# 69 is not dividable
# Wow
# 71 is not dividable
# 72 is not dividable
# 73 is not dividable
# 74 is not dividable
# Wow
# 76 is not dividable
# Kazow
# 78 is not dividable
# 79 is not dividable
# Wow
# 81 is not dividable
# 82 is not dividable
# 83 is not dividable
# Kazow
# Wow
# 86 is not dividable
# 87 is not dividable
# 88 is not dividable
# 89 is not dividable

# %%
# create a glasses class
class Glasses:
    #define inisialize method and pass color price and prescription to the object
    def __init__(self, color, price, prescription):
        # sets price to a varible only accessable by instance of object
        self.__price = price
        # set prescription to a variable
        self.__prescription = prescription
        # set color to variable 
        self.__color = color 
    # mutator method to set price
    def set_price(self, price):
        # set price to variable
        self.__price = price 
    # mutator method to set prescription
    def set_prescription(self, prescription):
        # set number to variable
        self.__prescription = prescription
    # accessor method to get price 
    def get_price(self):
        # return price
        return self.__price
    # accessor method to get prescription
    def get_prescription(self):
        # return prescription 
        return self.__prescription 
    # str method
    def __str__(self):
        return f'''Color is{self.__color}, 
        prescription is{self.__prescription}, price is {self.__price}'''
# define Bifocals subclass of Glasses   
class Bifocals(Glasses):
    # define initialize method and pass color, price, prescription, and reading_prescription
    def __init__(self, color, price, prescription, reading_prescription):
        # create the superclass method
        Glasses.__init__(self, color, price, prescription)
        # set subclass datat attributes
        # set reading prescription
        self.__reading_prescription = reading_prescription
        
    # mutator method to set reading prescription 
    def set_reading_presctription(self, reading_prescription):
        # set reading script to data attribute
        self.__reading_prescription = reading_prescription 
    # return reading_Prescription 
    def get_reading_prescription(self):
        return self.__reading_prescription
    # str method 
    def __str__(self):
        return f'''Reading script is {self.__reading_prescription}, color is{self.__color}, 
        prescription is{self.__prescription}, price is {self.__price}'''

# %%
# define main
def main():
    # for loop to iterate over a range
    for num in range(41,90):
        # call the function
        wow_kazow(num)
# define the function
def wow_kazow(num):
    # if even dividedly by 5 print wow
    if (num % 5) == 0:
        print((f'{num} is Wow'))
    # if evenly divide by 7 print kazow
    elif (num % 7) == 0:
        print(f'{num} is Kazow')
    # if evenly divided by 5 and 7 print wowkazow
    elif (num % 5) == 0 and (num % 7) == 0:
        print(f'{num} is WowKazow')
    # else just print the number 
    else:
        print(f'{num} is not dividable')
if __name__ == '__main__':
    # call main 
    main()
# Out:
# 41 is not dividable
# 42 is Kazow
# 43 is not dividable
# 44 is not dividable
# 45 is Wow
# 46 is not dividable
# 47 is not dividable
# 48 is not dividable
# 49 is Kazow
# 50 is Wow
# 51 is not dividable
# 52 is not dividable
# 53 is not dividable
# 54 is not dividable
# 55 is Wow
# 56 is Kazow
# 57 is not dividable
# 58 is not dividable
# 59 is not dividable
# 60 is Wow
# 61 is not dividable
# 62 is not dividable
# 63 is Kazow
# 64 is not dividable
# 65 is Wow
# 66 is not dividable
# 67 is not dividable
# 68 is not dividable
# 69 is not dividable
# 70 is Wow
# 71 is not dividable
# 72 is not dividable
# 73 is not dividable
# 74 is not dividable
# 75 is Wow
# 76 is not dividable
# 77 is Kazow
# 78 is not dividable
# 79 is not dividable
# 80 is Wow
# 81 is not dividable
# 82 is not dividable
# 83 is not dividable
# 84 is Kazow
# 85 is Wow
# 86 is not dividable
# 87 is not dividable
# 88 is not dividable
# 89 is not dividable

# %%
# create a glasses class
class Glasses:
    #define inisialize method and pass color price and prescription to the object
    def __init__(self, color, price, prescription):
        # sets price to a varible only accessable by instance of object
        self.__price = price
        # set prescription to a variable
        self.__prescription = prescription
        # set color to variable 
        self.__color = color 
    # mutator method to set price
    def set_price(self, price):
        # set price to variable
        self.__price = price 
    # mutator method to set prescription
    def set_prescription(self, prescription):
        # set number to variable
        self.__prescription = prescription
    # accessor method to get price 
    def get_price(self):
        # return price
        return self.__price
    # accessor method to get prescription
    def get_prescription(self):
        # return prescription 
        return self.__prescription 
    # str method
    def __str__(self):
        return f'''Color is{self.__color}, 
        prescription is{self.__prescription}, price is {self.__price}'''
# define Bifocals subclass of Glasses   
class Bifocals(Glasses):
    # define initialize method and pass color, price, prescription, and reading_prescription
    def __init__(self, color, price, prescription, reading_prescription):
        # create the superclass method
        Glasses.__init__(self, color, price, prescription)
        # set subclass datat attributes
        # set reading prescription
        self.__reading_prescription = reading_prescription
        
    # mutator method to set reading prescription 
    def set_reading_presctription(self, reading_prescription):
        # set reading script to data attribute
        self.__reading_prescription = reading_prescription 
    # return reading_Prescription 
    def get_reading_prescription(self):
        return self.__reading_prescription
    # str method 
    def __str__(self):
        return f'''Reading script is {self.__reading_prescription}, color is{self.__color}, 
        prescription is{self.__prescription}, price is {self.__price}'''
